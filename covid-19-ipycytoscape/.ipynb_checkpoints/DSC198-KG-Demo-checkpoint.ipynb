# %%
import ipycytoscape
import covidkg as cvkg
import pandas as pd
from covidkg import Node, Edge, KnowledgeGraph

# %%
nodes_data = pd.read_csv("data/nodes_data.csv")
interactions_data = pd.read_csv("data/interactions_data.csv")
tax_id = nodes_data["TaxonomyID"].astype(str)

color = ["blue" if i == '2697049' else "red" for i in tax_id.values]


href = "https://www.uniprot.org/uniprot/" + nodes_data["Identifier"].str[8:14]

# %%
kg = KnowledgeGraph()

def create_nodes(n_name, n_id, kg):
    for i in range(len(n_name)):
        kg.add_node(Node(n_name[i], n_id[i], tax_id[i], href[i], color[i]))

def create_edges(source, target, kg):
    for i in range(len(source)):
        kg.add_edge(Edge(Node("source_" + str(i), source[i]), Node("target_" + str(i), target[i])))
        
create_nodes(nodes_data["Name"], nodes_data["ID"], kg)

create_edges(interactions_data["SARS_COV2_Protein_ID"].values, interactions_data["Human_Protein_ID"].values, kg)

# %%
# Color code: {Blue: Viral, Red: Human}
kg.load_graph()
# Out:
# CytoscapeWidget(cytoscape_layout={'name': 'cola', 'nodeSpacing': 30}, cytoscape_style=[{'selector': 'node', 'c…

# %%
# View data
kg.data
# Out:
# {'nodes': [{'data': {'id': '375e0f905c315e06a99c80b736c125d2',
#     'name': 'E',
#     'taxonomy': '2697049',
#     'href': 'https://www.uniprot.org/uniprot/P0DTC4',
#     'color': 'blue'}},
#   {'data': {'id': '1cd6abff79ad3633e17582eb0e576539',
#     'name': 'M',
#     'taxonomy': '2697049',
#     'href': 'https://www.uniprot.org/uniprot/P0DTC5',
#     'color': 'blue'}},
#   {'data': {'id': '5c2c364f44079728c451280435c4236a',
#     'name': 'NSP1',
#     'taxonomy': '2697049',
#     'href': 'https://www.uniprot.org/uniprot/P0DTD1',
#     'color': 'blue'}},
#   {'data': {'id': '63d2c81f37726f44c600eb5225676a66',
#     'name': 'NSP11',
#     'taxonomy': '2697049',
#     'href': 'https://www.uniprot.org/uniprot/P0DTC1',
#     'color': 'blue'}},
#   {'data': {'id': 'af0cec59296f3c845a7b04500cd6886b',
#     'name': 'NSP10',
#     'taxonomy': '2697049',
#     'href': 'https://www.uniprot.org/uniprot/P0DTD1',
#     'color': 'blue'}},
#   {'data': {'id': 'b88e641d00c17a3ce19cc9852c37717c',
#     'name': 'NSP12',
#     'taxonomy': '2697049',
#     'href': 'https://www.uniprot.org/uniprot/P0DTD1',
#     'color': 'blue'}},
#   {'data': {'id': 'a489cf148afc7205eec14549ffe4ebfd',
#     'name': 'NSP13',
#     'taxonomy': '2697049',
#     'href': 'https://www.uniprot.org/uniprot/P0DTD1',
#     'color': 'blue'}},
#   {'data': {'id': '96fda12ecf3dcfec082377cc27e80e55',
#     'name': 'NSP14',
#     'taxonomy': '2697049',
#     'href': 'https://www.uniprot.org/uniprot/P0DTD1',
#     'color': 'blue'}},
#   {'data': {'id': 'b6e8ea75d0679d091b1dc44cf395aaf4',
#     'name': 'NSP5_C145A',
#     'taxonomy': '2697049',
#     'href': 'https://www.uniprot.org/uniprot/NSP5_C',
#     'color': 'blue'}},
#   {'data': {'id': '99424071c355c54269f6cd3522680033',
#     'name': 'NSP6',
#     'taxonomy': '2697049',
#     'href': 'https://www.uniprot.org/uniprot/P0DTD1',
#     'color': 'blue'}},
#   {'data': {'id': 'dc6436f559bc873ac013085f6e56d467',
#     'name': 'NSP5',
#     'taxonomy': '2697049',
#     'href': 'https://www.uniprot.org/uniprot/P0DTD1',
#     'color': 'blue'}},
#   {'data': {'id': '173be79f5a6fd85a7edb5c75cdc41fa3',
#     'name': 'NSP7',
#     'taxonomy': '2697049',
#     'href': 'https://www.uniprot.org/uniprot/P0DTD1',
#     'color': 'blue'}},
#   {'data': {'id': 'd7d018de059ea6b8c092267ff6371d38',
#     'name': 'NSP15',
#     'taxonomy': '2697049',
#     'href': 'https://www.uniprot.org/uniprot/P0DTD1',
#     'color': 'blue'}},
#   {'data': {'id': '073edb2349ddcd9a72ecd9f5c1dccdc4',
#     'name': 'NSP2',
#     'taxonomy': '2697049',
#     'href': 'https://www.uniprot.org/uniprot/P0DTD1',
#     'color': 'blue'}},
#   {'data': {'id': '6890e7e8e12f73c2dfdae6805ebc9c4f',
#     'name': 'NSP4',
#     'taxonomy': '2697049',
#     'href': 'https://www.uniprot.org/uniprot/P0DTD1',
#     'color': 'blue'}},
#   {'data': {'id': '20cfd282d01dd605a02d3d084ce320e9',
#     'name': 'ORF3B',
#     'taxonomy': '2697049',
#     'href': 'https://www.uniprot.org/uniprot/BI-254',
#     'color': 'blue'}},
#   {'data': {'id': '90b50e0be9abd893bd32b163d6933f0c',
#     'name': 'ORF6',
#     'taxonomy': '2697049',
#     'href': 'https://www.uniprot.org/uniprot/P0DTC6',
#     'color': 'blue'}},
#   {'data': {'id': 'f5c8b89ceac3f14e456577557df1ef40',
#     'name': 'ORF3A',
#     'taxonomy': '2697049',
#     'href': 'https://www.uniprot.org/uniprot/P0DTC3',
#     'color': 'blue'}},
#   {'data': {'id': '06bfef85cf1319e805e05f5bee3ec601',
#     'name': 'ORF10',
#     'taxonomy': '2697049',
#     'href': 'https://www.uniprot.org/uniprot/A0A663',
#     'color': 'blue'}},
#   {'data': {'id': '92ebecdcff1a59d6123f4e3133264695',
#     'name': 'NSP8',
#     'taxonomy': '2697049',
#     'href': 'https://www.uniprot.org/uniprot/P0DTD1',
#     'color': 'blue'}},
#   {'data': {'id': '8c32758bc2f4b49ed8c6dfe7caa7ea49',
#     'name': 'NSP9',
#     'taxonomy': '2697049',
#     'href': 'https://www.uniprot.org/uniprot/P0DTD1',
#     'color': 'blue'}},
#   {'data': {'id': 'f65213344e2e68de1cae4feb9c5e07b1',
#     'name': 'ORF7A',
#     'taxonomy': '2697049',
#     'href': 'https://www.uniprot.org/uniprot/P0DTC7',
#     'color': 'blue'}},
#   {'data': {'id': '14d0b1a958f970cb18618c9aa65493fa',
#     'name': 'ORF8',
#     'taxonomy': '2697049',
#     'href': 'https://www.uniprot.org/uniprot/P0DTC8',
#     'color': 'blue'}},
#   {'data': {'id': '9b66a6405fa5218ae819a76293365391',
#     'name': 'ORF9B',
#     'taxonomy': '2697049',
#     'href': 'https://www.uniprot.org/uniprot/P0DTD2',
#     'color': 'blue'}},
#   {'data': {'id': '74fa328ac0995fdbe2a3a0b2c4389f59',
#     'name': 'ORF9C',
#     'taxonomy': '2697049',
#     'href': 'https://www.uniprot.org/uniprot/P0DTD3',
#     'color': 'blue'}},
#   {'data': {'id': 'b100d0849c3e01fc6c75ead0e916ce0f',
#     'name': 'N',
#     'taxonomy': '2697049',
#     'href': 'https://www.uniprot.org/uniprot/P0DTC9',
#     'color': 'blue'}},
#   {'data': {'id': '4c35f09aac2f7be4f3cffd30c6aecac8',
#     'name': 'SPIKE',
#     'taxonomy': '2697049',
#     'href': 'https://www.uniprot.org/uniprot/P0DTC2',
#     'color': 'blue'}},
#   {'data': {'id': 'uniprot:Q8IWA5',
#     'name': 'CTL2_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q8IWA5',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q86VM9',
#     'name': 'ZCH18_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q86VM9',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q6UX04',
#     'name': 'CWC27_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q6UX04',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P25440',
#     'name': 'BRD2_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P25440',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9BSJ2',
#     'name': 'GCP2_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9BSJ2',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9BQT8',
#     'name': 'ODC_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9BQT8',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q96HW7',
#     'name': 'INT4_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q96HW7',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q96HR9',
#     'name': 'REEP6_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q96HR9',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q96ER3',
#     'name': 'SAAL1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q96ER3',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q96D53',
#     'name': 'COQ8B_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q96D53',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q96CW5',
#     'name': 'GCP3_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q96CW5',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q8NEW0',
#     'name': 'ZNT7_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q8NEW0',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q7L8L6',
#     'name': 'FAKD5_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q7L8L6',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q6PML9',
#     'name': 'ZNT9_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q6PML9',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q5JRX3',
#     'name': 'PREP_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q5JRX3',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q4KMQ2',
#     'name': 'ANO6_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q4KMQ2',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q10713',
#     'name': 'MPPA_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q10713',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q00765',
#     'name': 'REEP5_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q00765',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P48556',
#     'name': 'PSMD8_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P48556',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P38606',
#     'name': 'VATA_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P38606',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P38435',
#     'name': 'VKGC_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P38435',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P27105',
#     'name': 'STOM_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P27105',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P13804',
#     'name': 'ETFA_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P13804',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P11310',
#     'name': 'ACADM_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P11310',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P05026',
#     'name': 'AT1B1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P05026',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:O95070',
#     'name': 'YIF1A_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/O95070',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:O75439',
#     'name': 'MPPB_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/O75439',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q14181',
#     'name': 'DPOA2_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q14181',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P49643',
#     'name': 'PRI2_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P49643',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P49642',
#     'name': 'PRI1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P49642',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P09884',
#     'name': 'DPOLA_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P09884',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q99959',
#     'name': 'PKP2_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q99959',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q8NBJ5',
#     'name': 'GT251_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q8NBJ5',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:O75347',
#     'name': 'TBCA',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/O75347',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9HAV7',
#     'name': 'GRPE1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9HAV7',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q96CW1',
#     'name': 'AP2M1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q96CW1',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q969X5',
#     'name': 'ERGI1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q969X5',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P55789',
#     'name': 'ALR_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P55789',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:O94973',
#     'name': 'AP2A2_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/O94973',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9HAU0',
#     'name': 'PKHA5_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9HAU0',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9H2H8',
#     'name': 'PPIL3_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9H2H8',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q99081',
#     'name': 'HTF4_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q99081',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q96IZ5',
#     'name': 'RBM41_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q96IZ5',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q92615',
#     'name': 'LAR4B_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q92615',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q8IWR0',
#     'name': 'Z3H7A_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q8IWR0',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q70EL1',
#     'name': 'UBP54_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q70EL1',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q6UUV7',
#     'name': 'CRTC3_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q6UUV7',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q5VUA4',
#     'name': 'ZN318_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q5VUA4',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q5T6F2',
#     'name': 'UBAP2_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q5T6F2',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q5JSZ5',
#     'name': 'PRC2B_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q5JSZ5',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q5EBL8',
#     'name': 'PDZ11_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q5EBL8',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q2T9J0',
#     'name': 'TYSD1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q2T9J0',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q14157',
#     'name': 'UBP2L_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q14157',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q13546',
#     'name': 'RIPK1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q13546',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:O95391',
#     'name': 'SLU7_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/O95391',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:O75592',
#     'name': 'MYCB2_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/O75592',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:O43823',
#     'name': 'AKAP8_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/O43823',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:O14874',
#     'name': 'BCKD_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/O14874',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:A3KN83',
#     'name': 'SBNO1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/A3KN83',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P17612',
#     'name': 'KAPCA_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P17612',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:O14578',
#     'name': 'CTRO_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/O14578',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9Y2I6',
#     'name': 'NINL_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9Y2I6',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9UJC3',
#     'name': 'HOOK1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9UJC3',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9UHD2',
#     'name': 'TBK1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9UHD2',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9BV73',
#     'name': 'CP250_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9BV73',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9BV19',
#     'name': 'CA050_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9BV19',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9BQS8',
#     'name': 'FYCO1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9BQS8',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9BQQ3',
#     'name': 'GORS1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9BQQ3',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q99996',
#     'name': 'AKAP9_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q99996',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q96SN8',
#     'name': 'CK5P2_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q96SN8',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q96N16',
#     'name': 'JKIP1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q96N16',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q96CN9',
#     'name': 'GCC1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q96CN9',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q92995',
#     'name': 'UBP13_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q92995',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q8TD10',
#     'name': 'MIPO1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q8TD10',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q8N8E3',
#     'name': 'CE112_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q8N8E3',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q8N4C6',
#     'name': 'NIN_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q8N4C6',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q8N3C7',
#     'name': 'CLIP4_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q8N3C7',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q8IWJ2',
#     'name': 'GCC2_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q8IWJ2',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q8IUD2',
#     'name': 'RB6I2_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q8IUD2',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q7Z7A1',
#     'name': 'CNTRL_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q7Z7A1',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q76N32',
#     'name': 'CEP68_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q76N32',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q66GS9',
#     'name': 'CP135_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q66GS9',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q5VU43',
#     'name': 'MYOME_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q5VU43',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q5VT06',
#     'name': 'CE350_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q5VT06',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q4V328',
#     'name': 'GRAP1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q4V328',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q14789',
#     'name': 'GOGB1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q14789',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q08379',
#     'name': 'GOGA2_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q08379',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q08378',
#     'name': 'GOGA3_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q08378',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q08117',
#     'name': 'TLE5_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q08117',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q04726',
#     'name': 'TLE3_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q04726',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q04724',
#     'name': 'TLE1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q04724',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P49454',
#     'name': 'CENPF_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P49454',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P35241',
#     'name': 'RADI_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P35241',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P31323',
#     'name': 'KAP3_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P31323',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P13861',
#     'name': 'KAP2_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P13861',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:O95684',
#     'name': 'FR1OP_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/O95684',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:O95613',
#     'name': 'PCNT_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/O95613',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:O75506',
#     'name': 'HSBP1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/O75506',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:A7MCY6',
#     'name': 'TBKB1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/A7MCY6',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9NXA8',
#     'name': 'SIR5_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9NXA8',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P12268',
#     'name': 'IMDH2_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P12268',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P06280',
#     'name': 'AGAL_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P06280',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P07203',
#     'name': 'GPX1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P07203',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9NXH9',
#     'name': 'TRM1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9NXH9',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9H7F0',
#     'name': 'AT133_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9H7F0',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q99720',
#     'name': 'SGMR1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q99720',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q15904',
#     'name': 'VAS1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q15904',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:O75964',
#     'name': 'ATP5L_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/O75964',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q92769',
#     'name': 'HDAC2',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q92769',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q8WVC6',
#     'name': 'DCAKD_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q8WVC6',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9NP72',
#     'name': 'RAB18_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9NP72',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9H7Z7',
#     'name': 'PGES2_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9H7Z7',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9BQE4',
#     'name': 'SELS_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9BQE4',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q96DA6',
#     'name': 'TIM14_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q96DA6',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q96A26',
#     'name': 'F162A_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q96A26',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q8WUY8',
#     'name': 'NAT14_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q8WUY8',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q8WTV0',
#     'name': 'SCRB1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q8WTV0',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q8NBX0',
#     'name': 'SCPDL_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q8NBX0',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q8N183',
#     'name': 'NDUF2_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q8N183',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q7LGA3',
#     'name': 'HS2ST_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q7LGA3',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q6ZRP7',
#     'name': 'QSOX2_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q6ZRP7',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q5VT66',
#     'name': 'MARC1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q5VT66',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q5JTV8',
#     'name': 'TOIP1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q5JTV8',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q13724',
#     'name': 'MOGS_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q13724',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q12907',
#     'name': 'LMAN2_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q12907',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P63218',
#     'name': 'GBG5_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P63218',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P62873',
#     'name': 'GBB1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P62873',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P62820',
#     'name': 'RAB1A_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P62820',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P61586',
#     'name': 'RHOA_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P61586',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P61106',
#     'name': 'RAB14_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P61106',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P61026',
#     'name': 'RAB10_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P61026',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P61019',
#     'name': 'RAB2A_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P61019',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P61006',
#     'name': 'RAB8A_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P61006',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P51149',
#     'name': 'RAB7A_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P51149',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P51148',
#     'name': 'RAB5C_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P51148',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P21964',
#     'name': 'COMT_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P21964',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P11233',
#     'name': 'RALA_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P11233',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P00387',
#     'name': 'NB5R3_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P00387',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:O95573',
#     'name': 'ACSL3_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/O95573',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:O43169',
#     'name': 'CYB5B_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/O43169',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:O00116',
#     'name': 'ADAS_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/O00116',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9H4P4',
#     'name': 'RNF41_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9H4P4',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P62330',
#     'name': 'ARF6_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P62330',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P61970',
#     'name': 'NTF2_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P61970',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q6Y7W6',
#     'name': 'GGYF2_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q6Y7W6',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q5T1M5',
#     'name': 'FKB15_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q5T1M5',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q2M389',
#     'name': 'WASC4_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q2M389',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P52306',
#     'name': 'GDS1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P52306',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P16435',
#     'name': 'NCPR_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P16435',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:O60573',
#     'name': 'IF4E2_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/O60573',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:O14975',
#     'name': 'S27A2_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/O14975',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9Y5J7',
#     'name': 'TIM9_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9Y5J7',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9Y5J6',
#     'name': 'T10B_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9Y5J6',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9NVH1',
#     'name': 'DJC11_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9NVH1',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9BSF4',
#     'name': 'TIM29_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9BSF4',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q8TEM1',
#     'name': 'PO210_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q8TEM1',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q2TAA5',
#     'name': 'ALG11_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q2TAA5',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P62072',
#     'name': 'TIM10_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P62072',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P14735',
#     'name': 'IDE_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P14735',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9UJZ1',
#     'name': 'STML2',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9UJZ1',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9NZJ7',
#     'name': 'MTCH1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9NZJ7',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P78406',
#     'name': 'RAE1L_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P78406',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P52948',
#     'name': 'NUP98_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P52948',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9Y673',
#     'name': 'ALG5_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9Y673',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9UH99',
#     'name': 'SUN2_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9UH99',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9H270',
#     'name': 'VPS11_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9H270',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q96S66',
#     'name': 'CLCC1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q96S66',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q96JC1',
#     'name': 'VPS39_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q96JC1',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q8N6S5',
#     'name': 'AR6P6_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q8N6S5',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q8IWR1',
#     'name': 'TRI59_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q8IWR1',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P09601',
#     'name': 'HMOX1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P09601',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9C0D3',
#     'name': 'ZY11B_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9C0D3',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q15370',
#     'name': 'ELOB_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q15370',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q15369',
#     'name': 'ELOC_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q15369',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P62877',
#     'name': 'RBX1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P62877',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9Y5J9',
#     'name': 'TIM8B_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9Y5J9',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9BU02',
#     'name': 'THTPA_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9BU02',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q3KQU3',
#     'name': 'MA7D1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q3KQU3',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q13617',
#     'name': 'CUL2_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q13617',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P50897',
#     'name': 'PPT1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P50897',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9HD40',
#     'name': 'SPCS_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9HD40',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9BSC4',
#     'name': 'NOL10_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9BSC4',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q92552',
#     'name': 'RT27_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q92552',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q13868',
#     'name': 'EXOS2_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q13868',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P82675',
#     'name': 'RT05_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P82675',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9Y399',
#     'name': 'RT02_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9Y399',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9ULT8',
#     'name': 'HECD1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9ULT8',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9NY61',
#     'name': 'AATF_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9NY61',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9NQT5',
#     'name': 'EXOS3_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9NQT5',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9NQT4',
#     'name': 'EXOS5_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9NQT4',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9H6F5',
#     'name': 'CCD86_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9H6F5',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q96I59',
#     'name': 'SYNM_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q96I59',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q96B26',
#     'name': 'EXOS8_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q96B26',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q8NEJ9',
#     'name': 'NGDN_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q8NEJ9',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q7L2J0',
#     'name': 'MEPCE_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q7L2J0',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q4G0J3',
#     'name': 'LARP7_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q4G0J3',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q13206',
#     'name': 'DDX10_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q13206',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P82663',
#     'name': 'RT25_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P82663',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P61011',
#     'name': 'SRP54_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P61011',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P09132',
#     'name': 'SRP19_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P09132',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:O96028',
#     'name': 'NSD2_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/O96028',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:O95260',
#     'name': 'ATE1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/O95260',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:O76094',
#     'name': 'SRP72_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/O76094',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:O00566',
#     'name': 'MPP10_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/O00566',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P35556',
#     'name': 'FBN2_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P35556',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9UBX5',
#     'name': 'FBLN5_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9UBX5',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9NZL9',
#     'name': 'MAT2B_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9NZL9',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9BVL2',
#     'name': 'NUP58_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9BVL2',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q99567',
#     'name': 'NUP88_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q99567',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q96F45',
#     'name': 'ZN503_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q96F45',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q8TD19',
#     'name': 'NEK9_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q8TD19',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q8N0X7',
#     'name': 'SPART_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q8N0X7',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q86YT6',
#     'name': 'MIB1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q86YT6',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q7Z3B4',
#     'name': 'NUP54_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q7Z3B4',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q15056',
#     'name': 'IF4H_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q15056',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P61962',
#     'name': 'DCAF7_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P61962',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P37198',
#     'name': 'NUP62_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P37198',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P35658',
#     'name': 'NU214_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P35658',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P35555',
#     'name': 'FBN1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P35555',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P13984',
#     'name': 'T2FB_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P13984',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9NU22',
#     'name': 'MDN1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9NU22',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q7Z4Q2',
#     'name': 'HEAT3_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q7Z4Q2',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q96IV0',
#     'name': 'NGLY1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q96IV0',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q8N0Z8',
#     'name': 'PUSL1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q8N0Z8',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q96AY3',
#     'name': 'FKB10_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q96AY3',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q13443',
#     'name': 'ADAM9_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q13443',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9Y680',
#     'name': 'FKBP7_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9Y680',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9Y4L1',
#     'name': 'HYOU1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9Y4L1',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9UHI8',
#     'name': 'ATS1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9UHI8',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9P2E5',
#     'name': 'CHPF2_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9P2E5',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9NYU1',
#     'name': 'UGGG2_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9NYU1',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9NXK8',
#     'name': 'FXL12_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9NXK8',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9H8W4',
#     'name': 'PKHF2_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9H8W4',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9H4F8',
#     'name': 'SMOC1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9H4F8',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9H488',
#     'name': 'OFUT1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9H488',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9H173',
#     'name': 'SIL1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9H173',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9BZQ6',
#     'name': 'EDEM3_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9BZQ6',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9BS26',
#     'name': 'ERP44_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9BS26',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q9BRN9',
#     'name': 'TM2D3_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q9BRN9',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q99988',
#     'name': 'GDF15_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q99988',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q99519',
#     'name': 'NEUR1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q99519',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q99470',
#     'name': 'SDF2_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q99470',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q96MM7',
#     'name': 'H6ST2_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q96MM7',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q96F46',
#     'name': 'I17RA_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q96F46',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q96DZ1',
#     'name': 'ERLEC_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q96DZ1',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q92820',
#     'name': 'GGH_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q92820',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q8N766',
#     'name': 'EMC1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q8N766',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q8IZ52',
#     'name': 'CHSS2_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q8IZ52',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q8IWF2',
#     'name': 'FXRD2_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q8IWF2',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q8IV08',
#     'name': 'PLD3_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q8IV08',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q86YB8',
#     'name': 'ERO1B_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q86YB8',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q7Z4H8',
#     'name': 'PLGT3_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q7Z4H8',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q6UW63',
#     'name': 'PLGT2_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q6UW63',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q15818',
#     'name': 'NPTX1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q15818',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q13438',
#     'name': 'OS9_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q13438',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:Q08431',
#     'name': 'MFGM_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/Q08431',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P61916',
#     'name': 'NPC2_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P61916',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P58166',
#     'name': 'INHBE_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P58166',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P29122',
#     'name': 'PCSK6_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P29122',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P28300',
#     'name': 'LYOX_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P28300',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P26358',
#     'name': 'DNMT1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P26358',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P15151',
#     'name': 'PVR_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P15151',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P12109',
#     'name': 'CO6A1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P12109',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P0C7P0',
#     'name': 'CISD3_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P0C7P0',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P05556',
#     'name': 'ITB1_HUMAN',
#     'taxonomy': '9606',
#     'href': 'https://www.uniprot.org/uniprot/P05556',
#     'color': 'red'}},
#   {'data': {'id': 'uniprot:P00750',
#     'name': 'TPA_HUMAN',
#     'taxonomy': '9606',
# ...
#     'target': 'uniprot:O60573'}},
#   {'data': {'source': '073edb2349ddcd9a72ecd9f5c1dccdc4',
#     'target': 'uniprot:O14975'}},
#   {'data': {'source': '6890e7e8e12f73c2dfdae6805ebc9c4f',
#     'target': 'uniprot:Q9Y5J7'}},
#   {'data': {'source': '6890e7e8e12f73c2dfdae6805ebc9c4f',
#     'target': 'uniprot:Q9Y5J6'}},
#   {'data': {'source': '6890e7e8e12f73c2dfdae6805ebc9c4f',
#     'target': 'uniprot:Q9NVH1'}},
#   {'data': {'source': '6890e7e8e12f73c2dfdae6805ebc9c4f',
#     'target': 'uniprot:Q9BSF4'}},
#   {'data': {'source': '6890e7e8e12f73c2dfdae6805ebc9c4f',
#     'target': 'uniprot:Q8TEM1'}},
#   {'data': {'source': '6890e7e8e12f73c2dfdae6805ebc9c4f',
#     'target': 'uniprot:Q2TAA5'}},
#   {'data': {'source': '6890e7e8e12f73c2dfdae6805ebc9c4f',
#     'target': 'uniprot:P62072'}},
#   {'data': {'source': '6890e7e8e12f73c2dfdae6805ebc9c4f',
#     'target': 'uniprot:P14735'}},
#   {'data': {'source': '20cfd282d01dd605a02d3d084ce320e9',
#     'target': 'uniprot:Q9UJZ1'}},
#   {'data': {'source': '90b50e0be9abd893bd32b163d6933f0c',
#     'target': 'uniprot:Q9NZJ7'}},
#   {'data': {'source': '90b50e0be9abd893bd32b163d6933f0c',
#     'target': 'uniprot:P78406'}},
#   {'data': {'source': '90b50e0be9abd893bd32b163d6933f0c',
#     'target': 'uniprot:P52948'}},
#   {'data': {'source': 'f5c8b89ceac3f14e456577557df1ef40',
#     'target': 'uniprot:Q9Y673'}},
#   {'data': {'source': 'f5c8b89ceac3f14e456577557df1ef40',
#     'target': 'uniprot:Q9UH99'}},
#   {'data': {'source': 'f5c8b89ceac3f14e456577557df1ef40',
#     'target': 'uniprot:Q9H270'}},
#   {'data': {'source': 'f5c8b89ceac3f14e456577557df1ef40',
#     'target': 'uniprot:Q96S66'}},
#   {'data': {'source': 'f5c8b89ceac3f14e456577557df1ef40',
#     'target': 'uniprot:Q96JC1'}},
#   {'data': {'source': 'f5c8b89ceac3f14e456577557df1ef40',
#     'target': 'uniprot:Q8N6S5'}},
#   {'data': {'source': 'f5c8b89ceac3f14e456577557df1ef40',
#     'target': 'uniprot:Q8IWR1'}},
#   {'data': {'source': 'f5c8b89ceac3f14e456577557df1ef40',
#     'target': 'uniprot:P09601'}},
#   {'data': {'source': '06bfef85cf1319e805e05f5bee3ec601',
#     'target': 'uniprot:Q9C0D3'}},
#   {'data': {'source': '06bfef85cf1319e805e05f5bee3ec601',
#     'target': 'uniprot:Q15370'}},
#   {'data': {'source': '06bfef85cf1319e805e05f5bee3ec601',
#     'target': 'uniprot:Q15369'}},
#   {'data': {'source': '06bfef85cf1319e805e05f5bee3ec601',
#     'target': 'uniprot:P62877'}},
#   {'data': {'source': '06bfef85cf1319e805e05f5bee3ec601',
#     'target': 'uniprot:Q9Y5J9'}},
#   {'data': {'source': '06bfef85cf1319e805e05f5bee3ec601',
#     'target': 'uniprot:Q9BU02'}},
#   {'data': {'source': '06bfef85cf1319e805e05f5bee3ec601',
#     'target': 'uniprot:Q3KQU3'}},
#   {'data': {'source': '06bfef85cf1319e805e05f5bee3ec601',
#     'target': 'uniprot:Q13617'}},
#   {'data': {'source': '06bfef85cf1319e805e05f5bee3ec601',
#     'target': 'uniprot:P50897'}},
#   {'data': {'source': '92ebecdcff1a59d6123f4e3133264695',
#     'target': 'uniprot:Q9HD40'}},
#   {'data': {'source': '92ebecdcff1a59d6123f4e3133264695',
#     'target': 'uniprot:Q9BSC4'}},
#   {'data': {'source': '92ebecdcff1a59d6123f4e3133264695',
#     'target': 'uniprot:Q92552'}},
#   {'data': {'source': '92ebecdcff1a59d6123f4e3133264695',
#     'target': 'uniprot:Q13868'}},
#   {'data': {'source': '92ebecdcff1a59d6123f4e3133264695',
#     'target': 'uniprot:P82675'}},
#   {'data': {'source': '92ebecdcff1a59d6123f4e3133264695',
#     'target': 'uniprot:Q9Y399'}},
#   {'data': {'source': '92ebecdcff1a59d6123f4e3133264695',
#     'target': 'uniprot:Q9ULT8'}},
#   {'data': {'source': '92ebecdcff1a59d6123f4e3133264695',
#     'target': 'uniprot:Q9NY61'}},
#   {'data': {'source': '92ebecdcff1a59d6123f4e3133264695',
#     'target': 'uniprot:Q9NQT5'}},
#   {'data': {'source': '92ebecdcff1a59d6123f4e3133264695',
#     'target': 'uniprot:Q9NQT4'}},
#   {'data': {'source': '92ebecdcff1a59d6123f4e3133264695',
#     'target': 'uniprot:Q9H6F5'}},
#   {'data': {'source': '92ebecdcff1a59d6123f4e3133264695',
#     'target': 'uniprot:Q96I59'}},
#   {'data': {'source': '92ebecdcff1a59d6123f4e3133264695',
#     'target': 'uniprot:Q96B26'}},
#   {'data': {'source': '92ebecdcff1a59d6123f4e3133264695',
#     'target': 'uniprot:Q8NEJ9'}},
#   {'data': {'source': '92ebecdcff1a59d6123f4e3133264695',
#     'target': 'uniprot:Q7L2J0'}},
#   {'data': {'source': '92ebecdcff1a59d6123f4e3133264695',
#     'target': 'uniprot:Q4G0J3'}},
#   {'data': {'source': '92ebecdcff1a59d6123f4e3133264695',
#     'target': 'uniprot:Q13206'}},
#   {'data': {'source': '92ebecdcff1a59d6123f4e3133264695',
#     'target': 'uniprot:P82663'}},
#   {'data': {'source': '92ebecdcff1a59d6123f4e3133264695',
#     'target': 'uniprot:P61011'}},
#   {'data': {'source': '92ebecdcff1a59d6123f4e3133264695',
#     'target': 'uniprot:P09132'}},
#   {'data': {'source': '92ebecdcff1a59d6123f4e3133264695',
#     'target': 'uniprot:O96028'}},
#   {'data': {'source': '92ebecdcff1a59d6123f4e3133264695',
#     'target': 'uniprot:O95260'}},
#   {'data': {'source': '92ebecdcff1a59d6123f4e3133264695',
#     'target': 'uniprot:O76094'}},
#   {'data': {'source': '92ebecdcff1a59d6123f4e3133264695',
#     'target': 'uniprot:O00566'}},
#   {'data': {'source': '8c32758bc2f4b49ed8c6dfe7caa7ea49',
#     'target': 'uniprot:P35556'}},
#   {'data': {'source': '8c32758bc2f4b49ed8c6dfe7caa7ea49',
#     'target': 'uniprot:Q9UBX5'}},
#   {'data': {'source': '8c32758bc2f4b49ed8c6dfe7caa7ea49',
#     'target': 'uniprot:Q9NZL9'}},
#   {'data': {'source': '8c32758bc2f4b49ed8c6dfe7caa7ea49',
#     'target': 'uniprot:Q9BVL2'}},
#   {'data': {'source': '8c32758bc2f4b49ed8c6dfe7caa7ea49',
#     'target': 'uniprot:Q99567'}},
#   {'data': {'source': '8c32758bc2f4b49ed8c6dfe7caa7ea49',
#     'target': 'uniprot:Q96F45'}},
#   {'data': {'source': '8c32758bc2f4b49ed8c6dfe7caa7ea49',
#     'target': 'uniprot:Q8TD19'}},
#   {'data': {'source': '8c32758bc2f4b49ed8c6dfe7caa7ea49',
#     'target': 'uniprot:Q8N0X7'}},
#   {'data': {'source': '8c32758bc2f4b49ed8c6dfe7caa7ea49',
#     'target': 'uniprot:Q86YT6'}},
#   {'data': {'source': '8c32758bc2f4b49ed8c6dfe7caa7ea49',
#     'target': 'uniprot:Q7Z3B4'}},
#   {'data': {'source': '8c32758bc2f4b49ed8c6dfe7caa7ea49',
#     'target': 'uniprot:Q15056'}},
#   {'data': {'source': '8c32758bc2f4b49ed8c6dfe7caa7ea49',
#     'target': 'uniprot:P61962'}},
#   {'data': {'source': '8c32758bc2f4b49ed8c6dfe7caa7ea49',
#     'target': 'uniprot:P37198'}},
#   {'data': {'source': '8c32758bc2f4b49ed8c6dfe7caa7ea49',
#     'target': 'uniprot:P35658'}},
#   {'data': {'source': '8c32758bc2f4b49ed8c6dfe7caa7ea49',
#     'target': 'uniprot:P35555'}},
#   {'data': {'source': '8c32758bc2f4b49ed8c6dfe7caa7ea49',
#     'target': 'uniprot:P13984'}},
#   {'data': {'source': 'f65213344e2e68de1cae4feb9c5e07b1',
#     'target': 'uniprot:Q9NU22'}},
#   {'data': {'source': 'f65213344e2e68de1cae4feb9c5e07b1',
#     'target': 'uniprot:Q7Z4Q2'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:Q96IV0'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:Q8N0Z8'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:Q96AY3'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:Q13443'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:Q9Y680'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:Q9Y4L1'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:Q9UHI8'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:Q9P2E5'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:Q9NYU1'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:Q9NXK8'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:Q9H8W4'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:Q9H4F8'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:Q9H488'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:Q9H173'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:Q9BZQ6'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:Q9BS26'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:Q9BRN9'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:Q99988'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:Q99519'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:Q99470'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:Q96MM7'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:Q96F46'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:Q96DZ1'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:Q92820'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:Q8N766'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:Q8IZ52'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:Q8IWF2'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:Q8IV08'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:Q86YB8'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:Q7Z4H8'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:Q6UW63'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:Q15818'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:Q13438'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:Q08431'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:P61916'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:P58166'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:P29122'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:P28300'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:P26358'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:P15151'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:P12109'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:P0C7P0'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:P05556'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:P00750'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:O76061'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:O14656'}},
#   {'data': {'source': '14d0b1a958f970cb18618c9aa65493fa',
#     'target': 'uniprot:O00469'}},
#   {'data': {'source': '9b66a6405fa5218ae819a76293365391',
#     'target': 'uniprot:Q9UL15'}},
#   {'data': {'source': '9b66a6405fa5218ae819a76293365391',
#     'target': 'uniprot:Q9UKA9'}},
#   {'data': {'source': '9b66a6405fa5218ae819a76293365391',
#     'target': 'uniprot:Q9P0L2'}},
#   {'data': {'source': '9b66a6405fa5218ae819a76293365391',
#     'target': 'uniprot:Q9H773'}},
#   {'data': {'source': '9b66a6405fa5218ae819a76293365391',
#     'target': 'uniprot:Q9H2P9'}},
#   {'data': {'source': '9b66a6405fa5218ae819a76293365391',
#     'target': 'uniprot:Q7KZI7'}},
#   {'data': {'source': '9b66a6405fa5218ae819a76293365391',
#     'target': 'uniprot:P27448'}},
#   {'data': {'source': '9b66a6405fa5218ae819a76293365391',
#     'target': 'uniprot:O94826'}},
#   {'data': {'source': '9b66a6405fa5218ae819a76293365391',
#     'target': 'uniprot:O75534'}},
#   {'data': {'source': '9b66a6405fa5218ae819a76293365391',
#     'target': 'uniprot:O43633'}},
#   {'data': {'source': '9b66a6405fa5218ae819a76293365391',
#     'target': 'uniprot:O14745'}},
#   {'data': {'source': '74fa328ac0995fdbe2a3a0b2c4389f59',
#     'target': 'uniprot:Q9Y3A6'}},
#   {'data': {'source': '74fa328ac0995fdbe2a3a0b2c4389f59',
#     'target': 'uniprot:Q2PZI1'}},
#   {'data': {'source': '74fa328ac0995fdbe2a3a0b2c4389f59',
#     'target': 'uniprot:Q96S52'}},
#   {'data': {'source': '74fa328ac0995fdbe2a3a0b2c4389f59',
#     'target': 'uniprot:Q9Y6M9'}},
#   {'data': {'source': '74fa328ac0995fdbe2a3a0b2c4389f59',
#     'target': 'uniprot:Q9Y375'}},
#   {'data': {'source': '74fa328ac0995fdbe2a3a0b2c4389f59',
#     'target': 'uniprot:Q9Y276'}},
#   {'data': {'source': '74fa328ac0995fdbe2a3a0b2c4389f59',
#     'target': 'uniprot:Q9NV92'}},
#   {'data': {'source': '74fa328ac0995fdbe2a3a0b2c4389f59',
#     'target': 'uniprot:Q9H845'}},
#   {'data': {'source': '74fa328ac0995fdbe2a3a0b2c4389f59',
#     'target': 'uniprot:Q9H3K2'}},
#   {'data': {'source': '74fa328ac0995fdbe2a3a0b2c4389f59',
#     'target': 'uniprot:Q9GZU3'}},
#   {'data': {'source': '74fa328ac0995fdbe2a3a0b2c4389f59',
#     'target': 'uniprot:Q9BVK2'}},
#   {'data': {'source': '74fa328ac0995fdbe2a3a0b2c4389f59',
#     'target': 'uniprot:Q9BQ95'}},
#   {'data': {'source': '74fa328ac0995fdbe2a3a0b2c4389f59',
#     'target': 'uniprot:Q96K12'}},
#   {'data': {'source': '74fa328ac0995fdbe2a3a0b2c4389f59',
#     'target': 'uniprot:Q8TEQ8'}},
#   {'data': {'source': '74fa328ac0995fdbe2a3a0b2c4389f59',
#     'target': 'uniprot:Q86VR2'}},
#   {'data': {'source': '74fa328ac0995fdbe2a3a0b2c4389f59',
#     'target': 'uniprot:Q86UT6'}},
#   {'data': {'source': '74fa328ac0995fdbe2a3a0b2c4389f59',
#     'target': 'uniprot:Q7Z2K6'}},
#   {'data': {'source': '74fa328ac0995fdbe2a3a0b2c4389f59',
#     'target': 'uniprot:Q6NXT6'}},
#   {'data': {'source': '74fa328ac0995fdbe2a3a0b2c4389f59',
#     'target': 'uniprot:Q6NXT4'}},
#   {'data': {'source': '74fa328ac0995fdbe2a3a0b2c4389f59',
#     'target': 'uniprot:Q5BJF2'}},
#   {'data': {'source': '74fa328ac0995fdbe2a3a0b2c4389f59',
#     'target': 'uniprot:Q12770'}},
#   {'data': {'source': '74fa328ac0995fdbe2a3a0b2c4389f59',
#     'target': 'uniprot:P55085'}},
#   {'data': {'source': '74fa328ac0995fdbe2a3a0b2c4389f59',
#     'target': 'uniprot:P33527'}},
#   {'data': {'source': '74fa328ac0995fdbe2a3a0b2c4389f59',
#     'target': 'uniprot:O76024'}},
#   {'data': {'source': '74fa328ac0995fdbe2a3a0b2c4389f59',
#     'target': 'uniprot:O43292'}},
#   {'data': {'source': '74fa328ac0995fdbe2a3a0b2c4389f59',
#     'target': 'uniprot:O00124'}},
#   {'data': {'source': 'b100d0849c3e01fc6c75ead0e916ce0f',
#     'target': 'uniprot:Q9Y3U8'}},
#   {'data': {'source': 'b100d0849c3e01fc6c75ead0e916ce0f',
#     'target': 'uniprot:Q9NW13'}},
#   {'data': {'source': 'b100d0849c3e01fc6c75ead0e916ce0f',
#     'target': 'uniprot:Q9NR30'}},
#   {'data': {'source': 'b100d0849c3e01fc6c75ead0e916ce0f',
#     'target': 'uniprot:Q9UN86'}},
#   {'data': {'source': 'b100d0849c3e01fc6c75ead0e916ce0f',
#     'target': 'uniprot:Q9HCE1'}},
#   {'data': {'source': 'b100d0849c3e01fc6c75ead0e916ce0f',
#     'target': 'uniprot:Q92900'}},
#   {'data': {'source': 'b100d0849c3e01fc6c75ead0e916ce0f',
#     'target': 'uniprot:Q8TAD8'}},
#   {'data': {'source': 'b100d0849c3e01fc6c75ead0e916ce0f',
#     'target': 'uniprot:Q8NCA5'}},
#   {'data': {'source': 'b100d0849c3e01fc6c75ead0e916ce0f',
#     'target': 'uniprot:Q6PKG0'}},
#   {'data': {'source': 'b100d0849c3e01fc6c75ead0e916ce0f',
#     'target': 'uniprot:Q13310'}},
#   {'data': {'source': 'b100d0849c3e01fc6c75ead0e916ce0f',
#     'target': 'uniprot:Q13283'}},
#   {'data': {'source': 'b100d0849c3e01fc6c75ead0e916ce0f',
#     'target': 'uniprot:P67870'}},
#   {'data': {'source': 'b100d0849c3e01fc6c75ead0e916ce0f',
#     'target': 'uniprot:P19784'}},
#   {'data': {'source': 'b100d0849c3e01fc6c75ead0e916ce0f',
#     'target': 'uniprot:P11940'}},
#   {'data': {'source': 'b100d0849c3e01fc6c75ead0e916ce0f',
#     'target': 'uniprot:O43818'}},
#   {'data': {'source': '4c35f09aac2f7be4f3cffd30c6aecac8',
#     'target': 'uniprot:Q9C0B5'}},
#   {'data': {'source': '4c35f09aac2f7be4f3cffd30c6aecac8',
#     'target': 'uniprot:Q7Z5G4'}}]}
